# %%
# import package yfinance
import yfinance as yf

# tarik data saham (gunakan ".jk")
bbni = yf.Ticker("BBNI.JK")

#print data saham
bbni.info
# Out:
# {'address1': 'Gedung Grha BNI',
#  'address2': 'Jl. Jenderal Sudirman Kav. 1',
#  'city': 'Jakarta Pusat',
#  'zip': '10220',
#  'country': 'Indonesia',
#  'phone': '62 21 251 1946',
#  'fax': '62 21 251 1961',
#  'website': 'https://www.bni.co.id',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'PT Bank Negara Indonesia (Persero) Tbk, together with its subsidiaries, provides various banking products and services in Indonesia, New York, Europe, and Asia. It operates through, Corporate & International Banking, Institutional Banking, Enterprise & commercial Banking, Consumer Banking, Treasury, Head Offices, and Subsidiaries segments. The company offers savings account, savings plan and FIPF, loans, credit cards, simulation services, and others; and business banking, funding, lending, international trade financing, financial institution products, smart remittances, foreign direct investment, treasury products, and Solusi wholesale services, as well as services for micro small and medium enterprises. It also provides e-banking services, that includes ATM, phone banking, SMS notification, SMS banking, mobile banking, mobile services, BNI ipay, BNI Smartpay, BNI Agen46, BNI EDC, BNI debit online, internet payment gateway, open digital savings account, and QRIS, as well as wealth management services. In addition, the company offers life insurance, financing, securities, and venture capital services. PT Bank Negara Indonesia (Persero) Tbk was founded in 1946 and is headquartered in Jakarta Pusat, Indonesia.',
#  'fullTimeEmployees': 27386,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Royke  Tumilaar',
#    'age': 59,
#    'title': 'President Director & CEO',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Novita Widya Anggraini',
#    'age': 47,
#    'title': 'MD of Finance, CFO & Director',
#    'yearBorn': 1976,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Toto  Prasetio',
#    'age': 57,
#    'title': 'MD of Technology & Operations and Director',
#    'yearBorn': 1966,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Yohan Y. Setio C.F.A.',
#    'age': 36,
#    'title': 'Head of Investor Relations Division & Acting Chief of Economist',
#    'yearBorn': 1987,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mucharom Hadi Prayitno',
#    'title': 'MD of Human Capital & Compliance and Director',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. -  Johansyah',
#    'age': 41,
#    'title': 'Head of Legal Division',
#    'yearBorn': 1982,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Arom  Mucharom M.M., S.E.',
#    'age': 53,
#    'title': 'Head of Communications Division',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. -  Efrizal',
#    'age': 52,
#    'title': 'Head of Sales Division',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ayu Sari Wulandari',
#    'age': 53,
#    'title': 'Head of Data & Analytics Management Division',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Muhammad  Iqbal',
#    'age': 50,
#    'title': 'MD of Institutional Banking & Director',
#    'yearBorn': 1973,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 6000.0,
#  'open': 5925.0,
#  'dayLow': 5825.0,
#  'dayHigh': 5975.0,
#  'regularMarketPreviousClose': 6000.0,
#  'regularMarketOpen': 5925.0,
#  'regularMarketDayLow': 5825.0,
#  'regularMarketDayHigh': 5975.0,
#  'dividendRate': 196.39,
#  'dividendYield': 0.033299997,
#  'exDividendDate': 1679961600,
#  'payoutRatio': 0.35009998,
#  'fiveYearAvgDividendYield': 2.71,
#  'beta': 0.928,
#  'trailingPE': 10.515246,
#  'forwardPE': 8.20607,
#  'volume': 71774400,
#  'regularMarketVolume': 71774400,
#  'averageVolume': 47275006,
#  'averageVolume10days': 46180750,
#  'averageDailyVolume10Day': 46180750,
#  'bid': 5875.0,
#  'ask': 5875.0,
#  'marketCap': 219576176476160,
#  'fiftyTwoWeekLow': 4312.5,
#  'fiftyTwoWeekHigh': 6225.0,
#  'priceToSalesTrailing12Months': 4.5253625,
#  'fiftyDayAverage': 5631.5,
#  'twoHundredDayAverage': 4991.95,
#  'currency': 'IDR',
#  'enterpriseValue': 170897872781312,
#  'profitMargins': 0.43093,
#  'floatShares': 14861364280,
#  'sharesOutstanding': 578684032,
#  'heldPercentInsiders': 0.67894995,
#  'heldPercentInstitutions': 0.15994,
#  'impliedSharesOutstanding': 37371998208,
#  'bookValue': 4029.627,
#  'priceToBook': 1.4641554,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1703980800,
#  'earningsQuarterlyGrowth': 0.116,
#  'netIncomeToCommon': 20909475758080,
#  'trailingEps': 561.09,
#  'forwardEps': 718.98,
#  'pegRatio': 0.62,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1696896000,
#  'enterpriseToRevenue': 3.522,
#  '52WeekChange': 0.34090912,
#  'SandP52WeekChange': 0.2689098,
#  'lastDividendValue': 196.39006,
#  'lastDividendDate': 1679961600,
#  'exchange': 'JKT',
#  'quoteType': 'EQUITY',
#  'symbol': 'BBNI.JK',
#  'underlyingSymbol': 'BBNI.JK',
#  'shortName': 'Bank Negara Indonesia  (Persero',
#  'longName': 'PT Bank Negara Indonesia (Persero) Tbk',
#  'firstTradeDateEpochUtc': 1072144800,
#  'timeZoneFullName': 'Asia/Jakarta',
#  'timeZoneShortName': 'WIB',
#  'uuid': '00f27412-b186-39fd-8f0d-300b5ac8e018',
#  'messageBoardId': 'finmb_882643',
#  'gmtOffSetMilliseconds': 25200000,
#  'currentPrice': 5900.0,
#  'targetHighPrice': 6800.0,
#  'targetLowPrice': 5500.0,
#  'targetMeanPrice': 6389.8,
#  'targetMedianPrice': 6450.0,
#  'recommendationMean': 1.7,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 16,
#  'totalCash': 107511654907904,
#  'totalCashPerShare': 2885.692,
#  'totalDebt': 53992918876160,
#  'totalRevenue': 48521235398656,
#  'revenuePerShare': 1302.346,
#  'returnOnAssets': 0.01994,
#  'returnOnEquity': 0.14313,
#  'operatingCashflow': -27717921669120,
#  'earningsGrowth': 0.12,
#  'revenueGrowth': -0.03,
#  'operatingMargins': 0.36615002,
#  'financialCurrency': 'IDR',
#  'trailingPegRatio': None}

# %%
bbni.history(period="max")

# %%
# Mendapatkan dividen saham
bbni.dividends

# Mendapatkan histori Stocks Split saham
bbni.splits
# Out:
# Date
# 2004-07-02 00:00:00+07:00     11.238564
# 2005-06-24 00:00:00+07:00     55.965300
# 2006-06-16 00:00:00+07:00     25.245295
# 2007-06-20 00:00:00+07:00     34.365074
# 2008-06-18 00:00:00+07:00     13.935631
# 2009-06-19 00:00:00+07:00      3.792008
# 2009-11-26 00:00:00+07:00      4.474570
# 2010-06-09 00:00:00+07:00     22.505570
# 2011-06-13 00:00:00+07:00     32.990000
# 2012-05-11 00:00:00+07:00     31.240000
# 2013-04-29 00:00:00+07:00     56.675000
# 2014-04-29 00:00:00+07:00     72.855000
# 2014-04-30 00:00:00+07:00    145.710000
# 2015-03-25 00:00:00+07:00     72.274850
# 2016-03-18 00:00:00+07:00     61.266900
# 2017-03-24 00:00:00+07:00    106.403430
# 2017-03-27 00:00:00+07:00    212.806900
# 2018-03-28 00:00:00+07:00    127.777740
# 2019-05-22 00:00:00+07:00    100.644775
# 2020-03-02 00:00:00+07:00    103.120540
# 2021-04-08 00:00:00+07:00     22.011310
# 2022-03-24 00:00:00+07:00     73.148450
# 2023-03-28 00:00:00+07:00    196.390060
# Name: Dividends, dtype: float64

# %%
# import library yang kita butuhkan
import telebot
import yfinance as yf
import pandas as pd

#isikan token yang kita dapatkan
API_KEY = '7166054005:AAFKddSi1YDpuJpxxu1iIhqmXFHR7Bly5Og'
bot = telebot.TeleBot(API_KEY)

# contoh 
@bot.message_handler(commands=['Salam'])
def greet(message):
  bot.reply_to(message, "Halo, Saya StocksBotID siap membantu anda.")

@bot.message_handler(commands=['hello'])
def hello(message):
  bot.send_message(message.chat.id, "Hello!")

def stock_request(message):
  request = message.text.split()
  if len(request) < 2 or request[0].lower() not in "price":
    return False
  else:
    return True

@bot.message_handler(func=stock_request)
def send_price(message):
    request = message.text.split()[1]
    data = yf.download(tickers=request, period='5d', interval='1d')

    if data.size > 0:
        data["format_date"] = data.index.strftime('%m/%d %I:%M %p')
        response = data[['Close', 'format_date']].to_string(header=False)
        bot.send_message(message.chat.id, response)
    else:
        bot.send_message(message.chat.id, "No data!?")

def stock_info(message):
    request = message.text.split()
    if len(request) < 2 or request[0].lower() != "info":
        return False
    else:
        return True

@bot.message_handler(func=stock_info)
def send_info(message):
    request = message.text.split()[1]
    ticker = yf.Ticker(request)
    
    # Mengambil informasi umum tentang saham
    info = ticker.info

    # Membuat pesan balasan dengan membatasi jumlah informasi yang ditampilkan
    response = "Informasi tentang saham:\n"
    keys_to_display = ['shortName', 'longName', 'sector', 'country', 'marketCap', 'regularMarketPrice']
    for key in keys_to_display:
        if key in info:
            response += f"{key}: {info[key]}\n"

    # Mengirim pesan balasan kepada pengguna
    bot.send_message(message.chat.id, response)



bot.polling()
